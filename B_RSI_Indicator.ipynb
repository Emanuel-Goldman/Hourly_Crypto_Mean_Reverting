# %%
import pandas as pd
import numpy as np
import os
import multiprocessing as mp
import logging
import matplotlib.pyplot as plt 
pd.set_option('display.max_columns', 700)  # Show all columns
pd.set_option('display.max_rows', None)  # Show all columns
pd.set_option('display.float_format', '{:.5f}'.format)
WINDOW = 24

# %%
path = f'../../data/TUMTUMTUM/DF_Combined_2025_1h.csv'
df = pd.read_csv(path)
df['open_time'] = pd.to_datetime(df['open_time'])
df['open_time'] = pd.to_datetime(df['open_time']).dt.tz_localize(None)
print(f'DF shape - {df.shape}')


def get_coins(df: pd.DataFrame) -> list:
    cols = df.columns.tolist()
    coins = []
    for col in cols:
        if col.endswith('_open'):
            coin = col[:-5]
            coins.append(coin)
    return coins


df.head()
# Out:
# DF shape - (6785, 253)
#             open_time  BTCUSDT_open  BTCUSDT_high  BTCUSDT_low  BTCUSDT_close  \
# 0 2024-12-31 23:00:00   93469.10000   93736.90000  93356.60000    93548.90000
# 1 2025-01-01 00:00:00   93548.80000   94449.20000  93460.20000    94363.60000
# 2 2025-01-01 01:00:00   94363.60000   94363.70000  93545.00000    93588.00000
# 3 2025-01-01 02:00:00   93587.90000   94082.40000  93561.80000    94064.40000
# 4 2025-01-01 03:00:00   94064.40000   94070.20000  93692.60000    93810.00000
#
#    BTCUSDT_volume  BTCUSDT_RET  AAVEUSDT_open  AAVEUSDT_high  AAVEUSDT_low  \
# 0      3036.94600      0.00085      309.59000      311.66000     307.85000
# 1      5744.60900      0.00871      308.73000      313.72000     308.72000
# 2      3991.46400     -0.00822      313.61000      314.28000     311.37000
# 3      2297.23600      0.00509      313.37000      316.92000     313.21000
# 4      1928.71000     -0.00270      314.53000      314.58000     311.81000
#
#    AAVEUSDT_close  AAVEUSDT_volume  AAVEUSDT_RET  ADAUSDT_open  ADAUSDT_high  \
# 0       308.70000      16569.70000      -0.00287       0.84400       0.84640
# 1       313.61000      27473.90000       0.01591       0.84480       0.86070
# 2       313.37000      23172.20000      -0.00077       0.85920       0.85950
# 3       314.55000      26176.50000       0.00377       0.85280       0.85810
# 4       312.22000      13005.10000      -0.00741       0.85670       0.85720
#
#    ADAUSDT_low  ADAUSDT_close  ADAUSDT_volume  ADAUSDT_RET  ALGOUSDT_open  \
# 0      0.84170        0.84470        10080834      0.00071        0.33340
# 1      0.84340        0.85930        16915336      0.01728        0.33450
# 2      0.85220        0.85280         7916133     -0.00756        0.34080
# 3      0.85200        0.85670         6195489      0.00457        0.33650
# 4      0.85090        0.85190         6726879     -0.00560        0.34020
#
#    ALGOUSDT_high  ALGOUSDT_low  ALGOUSDT_close  ALGOUSDT_volume  ALGOUSDT_RET  \
# 0        0.33610       0.33290         0.33440    6425491.90000       0.00300
# 1        0.34130       0.33380         0.34080    9116021.50000       0.01914
# 2        0.34080       0.33570         0.33650    5713770.40000      -0.01262
# 3        0.34020       0.33640         0.34010    4686553.90000       0.01070
# 4        0.34080       0.33570         0.33580    3546236.30000      -0.01264
#
#    APTUSDT_open  APTUSDT_high  APTUSDT_low  APTUSDT_close  APTUSDT_volume  \
# 0       8.70260       8.74410      8.67540        8.71210    399404.20000
# 1       8.71200       8.80490      8.70140        8.80040    633195.20000
    """Add RSI columns for all *_close using Wilder smoothing."""
    close_cols = [c for c in df.columns if c.endswith('_close')]
    out = df.copy()

    for col in close_cols:
        d = out[col].diff()

        gain = d.clip(lower=0)
        loss = (-d).clip(lower=0)

        # Wilder smoothing: alpha = 1/window  <=>  com = window-1
        avg_gain = gain.ewm(com=window-1, min_periods=window, adjust=False).mean()
        avg_loss = loss.ewm(com=window-1, min_periods=window, adjust=False).mean()

        # Avoid div-by-zero and undefined 0/0
        rs = avg_gain / avg_loss.replace(0, np.nan)
        rsi = 100 - (100 / (1 + rs))

        # Edge cases:
        # avg_loss==0 & avg_gain>0 -> RSI=100 ; avg_gain==0 & avg_loss>0 -> RSI=0 ; both 0 -> 50
        both_zero = (avg_gain==0) & (avg_loss==0)
        rsi = rsi.where(~both_zero, 50)

        out[col.replace('_close', f'_RSI{window}')] = rsi

    out = out.dropna()
    return out

df = add_rsi_columns(df, window=WINDOW)
df[[c for c in df.columns if c.startswith('BCHUSDT')]].head()
# Out:
#     BCHUSDT_open  BCHUSDT_high  BCHUSDT_low  BCHUSDT_close  BCHUSDT_volume  \
# 24     449.51000     451.59000    449.26000      450.34000      6495.93500
# 25     450.35000     458.84000    450.25000      456.78000     15698.36500
# 26     456.78000     458.88000    454.64000      455.38000      8445.41300
# 27     455.38000     458.27000    454.76000      458.19000      4906.88100
# 28     458.20000     459.00000    456.43000      456.88000      4535.33100
#
#     BCHUSDT_RET  BCHUSDT_RSI24
# 24      0.00187       91.65827
# 25      0.01430       92.31607
# 26     -0.00306       90.69374
# 27      0.00617       91.02411
# 28     -0.00286       89.47887

# %%
def plot_price_rsi(df: pd.DataFrame, coin: str, rsi_window: int = 24, 
                   figsize=(22, 5), thr: int = 50) -> None:
    """
    Plot <coin>_close and <coin>_RSI{rsi_window} on dual y-axes,
    with horizontal RSI threshold lines.
    """
    price_col = f"{coin}_close"
    rsi_col = f"{coin}_RSI{rsi_window}"

    if price_col not in df.columns or rsi_col not in df.columns:
        print(f"Missing columns for {coin}: {price_col} or {rsi_col}")
        return

    ax = df[price_col].plot(figsize=figsize, color='tab:blue', label='Price')
    ax2 = ax.twinx()
    df[rsi_col].plot(ax=ax2, color='tab:orange', label=f'RSI{rsi_window}')

    # Add horizontal RSI threshold lines
    ax2.axhline(thr, color='green', linestyle='--', linewidth=1)

    ax.set_title(f"{coin} Price vs RSI{rsi_window}")
    ax.set_ylabel("Price")
    ax2.set_ylabel(f"RSI{rsi_window}")
    ax.legend(loc='upper left')
    ax2.legend(loc='upper right')

    plt.show()


plot_price_rsi(df, 'BCHUSDT', rsi_window=24)

# %%
def add_is_above_rsi_threashold(df: pd.DataFrame, window: int = 14, threshold: float = 50) -> pd.DataFrame:
    """Add *_IsAboveRSI columns (True if RSI > threshold)."""
    if df.columns[df.columns.str.endswith(f'IsAboveRSIThreshold')].any():
        print(f"IsAboveRSIThreshold columns found.")
        return df

    rsi_cols = [c for c in df.columns if c.endswith(f'_RSI{window}')]
    is_above = df[rsi_cols].gt(threshold)
    is_above.columns = [c.replace(f'_RSI{window}', '_IsAboveRSIThreshold') for c in rsi_cols]
    return pd.concat([df, is_above.astype('boolean')], axis=1)


df = add_is_above_rsi_threashold(df, window=WINDOW)
df[[c for c in df.columns if c.startswith('BCHUSDT')]].head()
# Out:
#     BCHUSDT_open  BCHUSDT_high  BCHUSDT_low  BCHUSDT_close  BCHUSDT_volume  \
# 24     449.51000     451.59000    449.26000      450.34000      6495.93500
# 25     450.35000     458.84000    450.25000      456.78000     15698.36500
# 26     456.78000     458.88000    454.64000      455.38000      8445.41300
# 27     455.38000     458.27000    454.76000      458.19000      4906.88100
# 28     458.20000     459.00000    456.43000      456.88000      4535.33100
#
#     BCHUSDT_RET  BCHUSDT_RSI24  BCHUSDT_IsAboveRSIThreshold
# 24      0.00187       91.65827                         True
# 25      0.01430       92.31607                         True
# 26     -0.00306       90.69374                         True
# 27      0.00617       91.02411                         True
# 28     -0.00286       89.47887                         True

# %%
def add_in_position_rsi(df: pd.DataFrame) -> pd.DataFrame:
    """Add *_InPosition columns (yesterday's IsAboveRSIThreshold)."""
    if df.columns[df.columns.str.endswith('_InPosition')].any():
        print("InPosition columns found.")
        return df

    is_above_cols = [c for c in df.columns if c.endswith('_IsAboveRSIThreshold')]
    in_pos = df[is_above_cols].shift(1)  # <-- shift by 1 to use yesterday’s signal
    in_pos.fillna(False, inplace=True)
    in_pos.columns = [c.replace('_IsAboveRSIThreshold', '_InPosition') for c in is_above_cols]

    return pd.concat([df, in_pos.astype('boolean')], axis=1)


df = add_in_position_rsi(df)
df[[c for c in df.columns if c.startswith('BCHUSDT')]].head()
# Out:
#     BCHUSDT_open  BCHUSDT_high  BCHUSDT_low  BCHUSDT_close  BCHUSDT_volume  \
# 24     449.51000     451.59000    449.26000      450.34000      6495.93500
# 25     450.35000     458.84000    450.25000      456.78000     15698.36500
# 26     456.78000     458.88000    454.64000      455.38000      8445.41300
# 27     455.38000     458.27000    454.76000      458.19000      4906.88100
# 28     458.20000     459.00000    456.43000      456.88000      4535.33100
#
#     BCHUSDT_RET  BCHUSDT_RSI24  BCHUSDT_IsAboveRSIThreshold  \
# 24      0.00187       91.65827                         True
# 25      0.01430       92.31607                         True
# 26     -0.00306       90.69374                         True
# 27      0.00617       91.02411                         True
# 28     -0.00286       89.47887                         True
#
#     BCHUSDT_InPosition
# 24               False
# 25                True
# 26                True
# 27                True
# 28                True

# %%
def add_entry_exit_flags(df: pd.DataFrame) -> pd.DataFrame:
    """
    Add both *_Entry and *_Exit columns:
      - Entry = 1 when prev bar was out (False) and current bar is in (True)
      - Exit  = 1 when prev bar was in (True) and current bar is out (False)
    """
    for col in df.columns:
        if col.endswith('_Entry'):
            print('Entry columns already exists.')
            return df
        
    out = df.copy()
    inpos_cols = [c for c in out.columns if c.endswith('_InPosition')]

    prev = out[inpos_cols].astype('boolean').shift(1).fillna(False)
    curr = out[inpos_cols].astype('boolean').fillna(False)

    # Entries: transition from 0 → 1
    entries = (~prev & curr).astype('int8')
    entries.columns = [c.replace('_InPosition', '_Entry') for c in inpos_cols]

    # Exits: transition from 1 → 0
    exits = (prev & ~curr).astype('int8')
    exits.columns = [c.replace('_InPosition', '_Exit') for c in inpos_cols]

    return pd.concat([out, entries, exits], axis=1)

df = add_entry_exit_flags(df)
df[[col for col in df.columns if col.startswith('JUPUSDT')]].head()
# Out:
#     JUPUSDT_open  JUPUSDT_high  JUPUSDT_low  JUPUSDT_close  JUPUSDT_volume  \
# 24       0.85120       0.85460      0.84750        0.85050          866206
# 25       0.85060       0.86900      0.84720        0.86290         3107363
# 26       0.86290       0.87100      0.85650        0.86110         1497422
# 27       0.86130       0.87450      0.85910        0.87310         1769991
# 28       0.87300       0.87530      0.86600        0.86860         1096542
#
#     JUPUSDT_RET  JUPUSDT_RSI24  JUPUSDT_IsAboveRSIThreshold  \
# 24     -0.00082       91.68041                         True
# 25      0.01458       92.07325                         True
# 26     -0.00209       91.41939                         True
# 27      0.01394       91.82334                         True
# 28     -0.00515       90.16243                         True
#
#     JUPUSDT_InPosition  JUPUSDT_Entry  JUPUSDT_Exit
# 24               False              0             0
# 25                True              1             0
# 26                True              0             0
# 27                True              0             0
# 28                True              0             0

# %%
def add_ret_in_out_position(df: pd.DataFrame) -> pd.DataFrame:
    """
    For each coin in df, add:
      - *_RET_InPosition: RET when InPosition is True, else 0
      - *_RET_OutOfPosition: RET when InPosition is False, else 0
    """
    out = df.copy()
    ret_cols = [c for c in df.columns if c.endswith('_RET')]

    for ret_col in ret_cols:
        base = ret_col.replace('_RET', '')
        pos_col = f"{base}_InPosition"
        if pos_col not in df.columns:
            continue

        out[f"{base}_RET_InPosition"] = df[ret_col].where(df[pos_col], 0)
        out[f"{base}_RET_OutOfPosition"] = df[ret_col].where(~df[pos_col], 0)

    return out

df = add_ret_in_out_position(df)
df[[col for col in df.columns if col.startswith('JUPUSDT')]].head()
# Out:
#     JUPUSDT_open  JUPUSDT_high  JUPUSDT_low  JUPUSDT_close  JUPUSDT_volume  \
# 24       0.85120       0.85460      0.84750        0.85050          866206
# 25       0.85060       0.86900      0.84720        0.86290         3107363
# 26       0.86290       0.87100      0.85650        0.86110         1497422
# 27       0.86130       0.87450      0.85910        0.87310         1769991
# 28       0.87300       0.87530      0.86600        0.86860         1096542
#
#     JUPUSDT_RET  JUPUSDT_RSI24  JUPUSDT_IsAboveRSIThreshold  \
# 24     -0.00082       91.68041                         True
# 25      0.01458       92.07325                         True
# 26     -0.00209       91.41939                         True
# 27      0.01394       91.82334                         True
# 28     -0.00515       90.16243                         True
#
#     JUPUSDT_InPosition  JUPUSDT_Entry  JUPUSDT_Exit  JUPUSDT_RET_InPosition  \
# 24               False              0             0                 0.00000
# 25                True              1             0                 0.01458
# 26                True              0             0                -0.00209
# 27                True              0             0                 0.01394
# 28                True              0             0                -0.00515
#
#     JUPUSDT_RET_OutOfPosition
# 24                   -0.00082
# 25                    0.00000
# 26                    0.00000
# 27                    0.00000
# 28                    0.00000

# %%
def add_all_cumulative_returns(df: pd.DataFrame) -> pd.DataFrame:
    """
    Adds cumulative return columns for each coin:
      - <COIN>_RET_CUM
      - <COIN>_RET_InPosition_CUM   (if exists)
      - <COIN>_RET_OutOfPosition_CUM (if exists)
    """
    ret_cols = [
        c for c in df.columns
        if c.endswith('_RET') and not c.endswith(('RET_InPosition', 'RET_OutOfPosition'))
    ]

    newcols = {}
    idx = df.index

    for ret_col in ret_cols:
        base = ret_col.replace('_RET', '')

        # total
        arr = (1 + df[ret_col].fillna(0)).to_numpy()
        newcols[f"{base}_RET_CUM"] = pd.Series(np.cumprod(arr) - 1, index=idx)

        # in / out (if present)
        in_col  = f"{base}_RET_InPosition"
        out_col = f"{base}_RET_OutOfPosition"

        if in_col in df.columns:
            arr_in = (1 + df[in_col].fillna(0)).to_numpy()
            newcols[f"{in_col}_CUM"] = pd.Series(np.cumprod(arr_in) - 1, index=idx)

        if out_col in df.columns:
            arr_out = (1 + df[out_col].fillna(0)).to_numpy()
            newcols[f"{out_col}_CUM"] = pd.Series(np.cumprod(arr_out) - 1, index=idx)

    # one join to avoid fragmentation
    return df.join(pd.DataFrame(newcols, index=idx))


df = add_all_cumulative_returns(df)
df[[col for col in df.columns if col.startswith('JUPUSDT')]].head()
# Out:
#     JUPUSDT_open  JUPUSDT_high  JUPUSDT_low  JUPUSDT_close  JUPUSDT_volume  \
# 24       0.85120       0.85460      0.84750        0.85050          866206
# 25       0.85060       0.86900      0.84720        0.86290         3107363
# 26       0.86290       0.87100      0.85650        0.86110         1497422
# 27       0.86130       0.87450      0.85910        0.87310         1769991
# 28       0.87300       0.87530      0.86600        0.86860         1096542
#
#     JUPUSDT_RET  JUPUSDT_RSI24  JUPUSDT_IsAboveRSIThreshold  \
# 24     -0.00082       91.68041                         True
# 25      0.01458       92.07325                         True
# 26     -0.00209       91.41939                         True
# 27      0.01394       91.82334                         True
# 28     -0.00515       90.16243                         True
#
#     JUPUSDT_InPosition  JUPUSDT_Entry  JUPUSDT_Exit  JUPUSDT_RET_InPosition  \
# 24               False              0             0                 0.00000
# 25                True              1             0                 0.01458
# 26                True              0             0                -0.00209
# 27                True              0             0                 0.01394
# 28                True              0             0                -0.00515
#
#     JUPUSDT_RET_OutOfPosition  JUPUSDT_RET_CUM  JUPUSDT_RET_InPosition_CUM  \
# 24                   -0.00082         -0.00082                     0.00000
# 25                    0.00000          0.01375                     0.01458
# 26                    0.00000          0.01163                     0.01246
# 27                    0.00000          0.02573                     0.02657
# 28                    0.00000          0.02044                     0.02128
#
#     JUPUSDT_RET_OutOfPosition_CUM
# 24                       -0.00082
# 25                       -0.00082
# 26                       -0.00082
# 27                       -0.00082
# 28                       -0.00082

# %%
def plot_avg_cumulative_returns_all(df: pd.DataFrame):
    """
    Plot average cumulative returns for:
      - total  → *_RET_CUM
      - in      → *_RET_InPosition_CUM
      - out     → *_RET_OutOfPosition_CUM
    All on the same figure.
    """
    modes = {
        "total": [c for c in df.columns if c.endswith('_RET_CUM') and 'InPosition' not in c and 'OutOfPosition' not in c],
        "in":    [c for c in df.columns if c.endswith('_RET_InPosition_CUM')],
        "out":   [c for c in df.columns if c.endswith('_RET_OutOfPosition_CUM')],
    }

    plt.figure(figsize=(10, 5))

    for mode, cols in modes.items():
        if not cols:
            continue

        avg_cum = df[cols].mean(axis=1)
        plt.plot(df.index, avg_cum, label=mode.capitalize())

    plt.title("Average Cumulative Returns (Total vs In vs Out of Position)")
    plt.xlabel("Time")
    plt.ylabel("Average Cumulative Return")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

plot_avg_cumulative_returns_all(df)
